# %% [markdown]
# Columns description :
#
# Age[15-49]All_gradeX : Percentage of the entire population ages 15 to 49 that has completed grade X
# Age[15-49]Male_gradeX : Percentage of the male population ages 15 to 49 that has completed grade X
# Age[15-49]Female_gradeX : Percentage of the female population ages 15 to 49 that has completed grade X
# X = [1...3]
#
# Instructions
#
# Step 1: Data exploration with Pandas
# Download the provided dataset
# Use pandas to read the file into a pandas Dataframe.
# Display general information about the dataset.
# Run descriptive analysis on the dataset using the 'describe' function.
# Step 2: Data exploration with ydata-profiling
# Use ydata-profiling to generate a report of the provided dataset.
# Look for missing values in the dataset. You can use the report generated by ydata to identify missing values.
# Examine the correlations between different columns in the dataset. You can use the report generated by ydata to identify correlations.
# Identify any other interesting patterns or insights in the dataset that you can discover through the ydata-profiling report.
# Step 3: Summary
# Write a summary of your findings based on the ydata-profiling report. Be sure to include any interesting patterns or insights you discovered in the dataset.

# %%
#ydata profiling
import pandas as pd

# %% [markdown]
# ## Step 1: DATA EXPLORATION WITH PANDAS

# %%
#Downloading the provided dataset
Education_dataset = pd.read_csv("Documents/EDUCATION_ATTAINMENT.csv")

# %%
#Using pandas to read the file into a pandas Dataframe.

# %%
#Displaying general information about the dataset
Education_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 626 entries, 0 to 625
# Data columns (total 38 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Ages[15-49]_All_grade1     626 non-null    float64
#  1   Ages[15-49]_All_grade2     626 non-null    float64
#  2   Ages[15-49]_All_grade3     626 non-null    float64
#  3   Ages[20-29]_All_grade1     626 non-null    float64
#  4   Ages[20-29]_All_grade2     626 non-null    float64
#  5   Ages[20-29]_All_grade3     626 non-null    float64
#  6   Ages[30-39]_All_grade1     625 non-null    float64
#  7   Ages[30-39]_All_grade2     625 non-null    float64
#  8   Ages[30-39]_All_grade3     625 non-null    float64
#  9   Ages[40-49]_All_grade1     625 non-null    float64
#  10  Ages[40-49]_All_grade2     625 non-null    float64
#  11  Ages[40-49]_All_grade3     625 non-null    float64
#  12  Ages[15-49]_Male_grade1    626 non-null    float64
# ...

# %%
#Descriptive analysis of the dataset using the describe function
Education_dataset.describe()
# Out:
#        Ages[15-49]_All_grade1  Ages[15-49]_All_grade2  Ages[15-49]_All_grade3  \
# count              626.000000              626.000000              626.000000
# mean                 0.873886                0.861490                0.837509
# std                  0.162624                0.166895                0.176555
# min                  0.251917                0.244071                0.233274
# 25%                  0.831791                0.803131                0.757465
# 50%                  0.948926                0.935167                0.909587
# 75%                  0.984447                0.980112                0.971166
# max                  1.000000                1.000000                1.000000
#
#        Ages[20-29]_All_grade1  Ages[20-29]_All_grade2  Ages[20-29]_All_grade3  \
# count              626.000000              626.000000              626.000000
# mean                 0.823849                0.812738                0.789965
# ...

# %% [markdown]
# ### Step 2: Data exploration with ydata-profiling

# %%
#Installing ydata profiling
# !pip install pandas-profiling
#ydata profiling

# %%
#searching for missing values in a dataset
num_rows = Education_dataset.shape[0]

#Finding the sample size
sample_size = min(100, num_rows) #Sample size should not exceed the number of rows

# %%
#Picking a random sample
sample_df= Education_dataset.sample (n=sample_size, random_state = 28)

# %%
sample_df
# Out:
#      Ages[15-49]_All_grade1  Ages[15-49]_All_grade2  Ages[15-49]_All_grade3  \
# 411                0.938053                0.933750                0.924609
# 283                0.954713                0.946951                0.921526
# 327                0.987450                0.985275                0.979276
# 469                0.664049                0.655185                0.631952
# 230                0.952579                0.938738                0.910717
# ..                      ...                     ...                     ...
# 155                0.882800                0.875438                0.862988
# 610                0.911825                0.890937                0.854729
# 122                0.983079                0.975480                0.949112
# 551                1.000000                1.000000                1.000000
# 557                0.888811                0.876738                0.862149
#
# ...

# %%
#Generate the profile report
profile = ProfileReport(sample_df, title= 'Pandas Profiling Report')

# %%
#Generate an HTML report
profile.to_file("sample_df.html")

# %% [markdown]
# ## In looking for missing values in the dataset, Use the report generated by ydata to identify it

# %% [markdown]
# ## Examine the correlations between different columns in the dataset.You can use the report generated to identify correlations.

# %%
missing_values = sample_df.isnull().sum()
print("Missing values per column using isnull() and sum(): ")
print(missing_values)
# Out:
# Missing values per column using isnull() and sum():
# Ages[15-49]_All_grade1       0
# Ages[15-49]_All_grade2       0
# Ages[15-49]_All_grade3       0
# Ages[20-29]_All_grade1       0
# Ages[20-29]_All_grade2       0
# Ages[20-29]_All_grade3       0
# Ages[30-39]_All_grade1       1
# Ages[30-39]_All_grade2       1
# Ages[30-39]_All_grade3       1
# Ages[40-49]_All_grade1       1
# Ages[40-49]_All_grade2       1
# Ages[40-49]_All_grade3       1
# Ages[15-49]_Male_grade1      0
# Ages[15-49]_Male_grade2      0
# Ages[15-49]_Male_grade3      0
# Ages[20-29]_Male_grade1      0
# Ages[20-29]_Male_grade2      0
# Ages[20-29]_Male_grade3      0
# Ages[30-39]_Male_grade1      1
# Ages[30-39]_Male_grade2      1
# Ages[30-39]_Male_grade3      1
# Ages[40-49]_Male_grade1      1
# Ages[40-49]_Male_grade2      1
# Ages[40-49]_Male_grade3      1
# Ages[15-49]_Female_grade1    0
# Ages[15-49]_Female_grade2    0
# Ages[15-49]_Female_grade3    0
# Ages[20-29]_Female_grade1    0
# ...

# %% [markdown]
# ## Examine the correlations between different columns in the dataset. You can use the report generated by ydata to identify correlations.

# %%
The correlations between different columns in the dataset has a relationship that is strongly positive

# %% [markdown]
# ## Identify any other interesting patterns or insights in the dataset that you can discover through the ydata-profiling report.

# %%
The termed dataset has a population, male and female consisting of various age grades. Focus is being played on individuals aged 15-49. For each subgroup, the performance of all grades is analyzed
Strong correlation between the scores of different grades, indicating that individuals who perform well in one grade are likely to perform well in others as well

High Scores Across Grades: The means for all grades are relatively high

Interesting Spread: The IQR and standard deviation increase slightly from grade 1 to grade 3, the spread is broader in higher grades

Correlation: High correlation indicates that the scores in one grade are likely predictive of the score in another grade
